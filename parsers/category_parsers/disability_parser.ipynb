# %% [markdown]
# ### 카테고리별 지원 파싱 (장애인지원)
# 장애인지원 (238~293페이지) 파싱

# %%
import os
import json
import time
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from pydantic import BaseModel, Field
import fitz

load_dotenv()
# Out:
# True

# %%
class TableData(BaseModel):
    columns: list = Field(description="표의 열 제목들")
    rows: list = Field(description="표의 행 데이터들")

class WelfareProgram(BaseModel):
    title: str = Field(description="복지 프로그램의 정확한 지원명")
    target: str = Field(description="지원 대상자")
    content: str = Field(description="지원 내용")
    method: str = Field(description="신청 방법")
    inquiry: str = Field(description="문의처")
    tables: list[TableData] = Field(description="표 데이터 구조")

# %%
def extract_page_text(pdf_path, page_num):
    doc = fitz.open(pdf_path)
    page = doc.load_page(page_num - 1)
    text = page.get_text("text")
    doc.close()
    return text

# %%
def parse_disability_support(text, page_num):
    llm = ChatOpenAI(
        model="gpt-3.5-turbo",
        temperature=0,
        request_timeout=60,
        max_retries=3
    )
    
    parser = JsonOutputParser(pydantic_object=WelfareProgram)
    
    prompt = ChatPromptTemplate.from_messages([
        ("system", """장애인지원 문서 전용 파서입니다.

검증 로직:
1. "대상", "내용", "방법", "문의" 4개 필수 키워드 존재 확인
2. 키워드 중 하나라도 없으면 null 반환

제도명 추출 규칙:
- "나에게 힘이 되는 복지서비스"는 페이지 헤더이므로 제외
- "장애인 지원"은 카테고리명이므로 제외
- 실제 제도명만 추출 (예: "장애인연금", "장애인활동지원", "발달장애인 부모상담지원")

표 처리 규칙:
1. content: 표 내용을 자연어로 요약하여 포함
2. tables: 표가 있으면 구조화된 데이터로 저장
   - columns: 실제 표의 열 제목을 정확히 추출 (예: ["장애등급", "월지급액", "비고"])
   - rows: 실제 표의 행 데이터를 정확히 추출 (예: [["중증", "43만원", "기초급여+부가급여"]])
   - 표의 실제 구조를 그대로 반영하여 저장
3. 표가 없으면 tables는 빈 배열

추출 최적화:
- 제도명: 실제 장애인지원제도명만
- 대상: 장애유형, 장애등급, 소득기준 등 구체적 조건
- 내용: 지원금액, 지원기간, 지원내용 (표 데이터 요약 포함)
- 방법: 신청기관, 온라인/오프라인 구분, 필요서류
- 문의: 콜센터, 웹사이트, 담당기관
- tables: 표가 있으면 실제 컬럼명과 데이터로 구조화하여 저장

{format_instructions}"""),

        ("human", """장애인지원 문서를 분석합니다.

1단계: 필수 키워드 확인
- "대상", "내용", "방법", "문의" 4개 키워드 모두 존재하는지 확인
- 하나라도 없으면 null 반환

2단계: 제도명 추출
- "나에게 힘이 되는 복지서비스" 제외
- "장애인 지원" 제외
- 실제 장애인지원제도명만 추출

3단계: 정보 추출
- content: 표 내용을 자연어로 요약하여 포함
- tables: 표가 있으면 실제 컬럼명과 행 데이터를 정확히 추출하여 저장
- 각 키워드 바로 다음 내용을 정확히 추출

텍스트:
{text}
""")
    ])
    
    chain = prompt | llm | parser
    
    for attempt in range(3):
        try:
            result = chain.invoke({
                "text": text,
                "format_instructions": parser.get_format_instructions()
            })
            
            if result is None:
                print(f"페이지 {page_num}: 필수 키워드 부족으로 건너뛰기")
                return None
            
            result["page"] = page_num
            result["category"] = "장애인지원"
            
            return result
        except Exception as e:
            print(f"파싱 시도 {attempt + 1}/3 실패 (페이지 {page_num}): {e}")
            if attempt < 2:
                time.sleep(2)
            else:
                return None

# %%
# 실행
pdf_path = "../../data/pdfs/[통합]+2025+나에게+힘이+되는+복지서비스.pdf"
target_pages = list(range(238, 294))  # 장애인지원 섹션 (238~293페이지)
disability_programs = []

for i, page_num in enumerate(target_pages):
    print(f"페이지 {page_num} 파싱 중... ({i+1}/{len(target_pages)})")
    
    page_text = extract_page_text(pdf_path, page_num)
    program = parse_disability_support(page_text, page_num)
    
    if program:
        disability_programs.append(program)
        table_count = len(program.get('tables', []))
        print(f" {program['title']} 추출 완료 (표 {table_count}개)")
    else:
        print(f"페이지 {page_num} 건너뛰기")
    
    if i < len(target_pages) - 1:
        time.sleep(1)
# Out:
# 페이지 238 파싱 중... (1/56)
#  장애인 지원 추출 완료 (표 0개)
# 페이지 239 파싱 중... (2/56)
#  장애인 서비스지원 종합조사 신청 추출 완료 (표 0개)
# 페이지 240 파싱 중... (3/56)
#  장애아동수당 추출 완료 (표 1개)
# 페이지 241 파싱 중... (4/56)
#  장애수당 추출 완료 (표 1개)
# 페이지 242 파싱 중... (5/56)
#  장애인연금 추출 완료 (표 1개)
# 페이지 243 파싱 중... (6/56)
#  여성장애인 출산비용 지원 추출 완료 (표 0개)
# 페이지 244 파싱 중... (7/56)
#  장애아 보육료 지원 추출 완료 (표 1개)
# 페이지 245 파싱 중... (8/56)
#  발달장애인 가족휴식 지원 추출 완료 (표 0개)
# 페이지 246 파싱 중... (9/56)
#  발달장애인 부모 상담 지원 추출 완료 (표 0개)
# 페이지 247 파싱 중... (10/56)
#  장애아 방과후 보육료 지원 추출 완료 (표 0개)
# 페이지 248 파싱 중... (11/56)
#  특수교육대상자 치료지원 서비스 추출 완료 (표 0개)
# 페이지 249 파싱 중... (12/56)
#  국립특수학교 및 국립부설학교 특수학급 지원 추출 완료 (표 0개)
# 페이지 250 파싱 중... (13/56)
#  장애인 정보화교육 추출 완료 (표 1개)
# 페이지 251 파싱 중... (14/56)
#  장애인 일자리 지원 추출 완료 (표 1개)
# 페이지 252 파싱 중... (15/56)
#  중증장애인 직업재활 지원 추출 완료 (표 0개)
# 페이지 253 파싱 중... (16/56)
#  장애인직업재활시설 이용 추출 완료 (표 1개)
# 페이지 254 파싱 중... (17/56)
#  중증장애인생산품 우선구매 추출 완료 (표 0개)
# 페이지 255 파싱 중... (18/56)
#  장애인 취업성공패키지 추출 완료 (표 1개)
# 페이지 256 파싱 중... (19/56)
#  중증장애인 근로지원인 추출 완료 (표 0개)
# 페이지 257 파싱 중... (20/56)
#  장애인 신규 고용장려금 지원 추출 완료 (표 1개)
# 페이지 258 파싱 중... (21/56)
#  중증장애인 지원고용(훈련수당) 추출 완료 (표 0개)
# 페이지 259 파싱 중... (22/56)
#  장애인 직업능력개발 운영(훈련수당) 추출 완료 (표 1개)
# 페이지 260 파싱 중... (23/56)
#  근로장애인 전환지원 추출 완료 (표 1개)
# 페이지 261 파싱 중... (24/56)
#  장애인고용 시설장비 융자･무상지원 추출 완료 (표 1개)
# 페이지 262 파싱 중... (25/56)
#  장애인 표준사업장 설립 지원 추출 완료 (표 0개)
# 페이지 263 파싱 중... (26/56)
#  근로지원비용 지원 추출 완료 (표 0개)
# 페이지 264 파싱 중... (27/56)
#  보조공학기기 지원 추출 완료 (표 1개)
# 페이지 265 파싱 중... (28/56)
# 페이지 265: 필수 키워드 부족으로 건너뛰기
# 페이지 265 건너뛰기
# 페이지 266 파싱 중... (29/56)
#  장애인 창업점포 지원사업 추출 완료 (표 0개)
# 페이지 267 파싱 중... (30/56)
#  장애인 창업육성 추출 완료 (표 2개)
# 페이지 268 파싱 중... (31/56)
#  정보통신 보조기기 보급 추출 완료 (표 1개)
# 페이지 269 파싱 중... (32/56)
#  장애인 의료비 지원 추출 완료 (표 1개)
# 페이지 270 파싱 중... (33/56)
#  장애인 건강보험료 경감 추출 완료 (표 0개)
# 페이지 271 파싱 중... (34/56)
#  장애인 보조기기 급여 추출 완료 (표 0개)
# 페이지 272 파싱 중... (35/56)
#  장애정도 심사 검사비 지원 추출 완료 (표 0개)
# 페이지 273 파싱 중... (36/56)
#  장애인 보조기기 교부 추출 완료 (표 1개)
# 페이지 274 파싱 중... (37/56)
#  언어발달 지원 추출 완료 (표 0개)
# 페이지 275 파싱 중... (38/56)
#  발달재활서비스 추출 완료 (표 0개)
# 페이지 276 파싱 중... (39/56)
#  지역장애인보건의료센터 추출 완료 (표 0개)
# 페이지 277 파싱 중... (40/56)
#  장애친화 건강검진 추출 완료 (표 0개)
# 페이지 278 파싱 중... (41/56)
#  장애인 재활지원 사업 추출 완료 (표 1개)
# 페이지 279 파싱 중... (42/56)
#  장애인 활동지원 추출 완료 (표 1개)
# 페이지 280 파싱 중... (43/56)
#  성인 발달장애인 주간활동 서비스 추출 완료 (표 0개)
# 페이지 281 파싱 중... (44/56)
#  여성장애인 가사도우미 파견 추출 완료 (표 0개)
# 페이지 282 파싱 중... (45/56)
#  장애인 거주시설 이용 추출 완료 (표 0개)
# 페이지 283 파싱 중... (46/56)
#  무료 법률구조 제도 추출 완료 (표 0개)
# 페이지 284 파싱 중... (47/56)
#  장애인 자동차 표지 발급 추출 완료 (표 0개)
# 페이지 285 파싱 중... (48/56)
#  장애인 운전교육 사업 추출 완료 (표 0개)
# 페이지 286 파싱 중... (49/56)
#  장애인 건강주치의 시범사업 추출 완료 (표 0개)
# 페이지 287 파싱 중... (50/56)
#  장애인 전용 승용자동차에 대한 개별소비세 면제 추출 완료 (표 0개)
# 페이지 288 파싱 중... (51/56)
#  장애인용 자동차에 대한 지방세 감면 추출 완료 (표 0개)
# 페이지 289 파싱 중... (52/56)
#  장애인보조기기 부가가치세 영세율 적용 추출 완료 (표 0개)
# 페이지 290 파싱 중... (53/56)
#  지역사회 복지시설 이용 지원 추출 완료 (표 0개)
# 페이지 291 파싱 중... (54/56)
#  장애인 체육시설 추출 완료 (표 0개)
# 페이지 292 파싱 중... (55/56)
#  장애예술 활성화 지원 사업 추출 완료 (표 0개)
# 페이지 293 파싱 중... (56/56)
#  장애인을 위한 요금감면제도 추출 완료 (표 1개)

# %%
# 결과 저장
os.makedirs("outputs", exist_ok=True)
output_path = "../../data/outputs/장애인지원_2025.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(disability_programs, f, ensure_ascii=False, indent=2)

print(f"\n 파싱 완료: {len(disability_programs)}개 프로그램")
print(f"저장 위치: {output_path}")
# Out:
#  파싱 완료: 55개 프로그램
# 저장 위치: ../../data/outputs/장애인지원_2025.json

# %%
for program in disability_programs:
    table_count = len(program.get('tables', []))
    print(f"\n{program['title']} (페이지 {program['page']}, 표 {table_count}개)")
    print(f"대상: {program['target'][:80]}...")
    print(f"내용: {program['content'][:80]}...")
    if table_count > 0:
        print(f"표: {program['tables'][0]['columns'][:3]}...")
# Out:
# 장애인 지원 (페이지 238, 표 0개)
# 대상: 장애로 인해 생활이 곤란한 중증장애인...
# 내용: 매월 일정 금액을 지원하여 안정적으로 생활할 수 있도록 지원합니다....
#
# 장애인 서비스지원 종합조사 신청 (페이지 239, 표 0개)
# 대상: 등록 장애인...
# 내용: 서비스지원 종합조사를 통해 대상자를 선정하고 필요한 서비스를 제공합니다. 대상은 ① 일상생활지원 분야(활동지원, 거주시설, 보조기기, 주간활동,...
#
# 장애아동수당 (페이지 240, 표 1개)
# 대상: 18세 미만의 등록 장애아동 중 기초생활수급자 또는 차상위계층...
# 내용: 18세 미만의 등록 장애아동 중 기초생활수급자 또는 차상위계층을 대상으로 하며, 소득 수준 및 주거형태에 따라 매월 장애아동수당을 지급합니다. ...
# 표: ['구분', '중증장애아동수당', '경증장애아동수당']...
#
# 장애수당 (페이지 241, 표 1개)
# 대상: 18세 이상의 장애인연금법상 중증장애인에 해당하지 않는 등록장애인 중 기초생활수급자 또는 차상위계층...
# 내용: 18세 이상의 중증장애인에 해당하지 않는 등록장애인 중 기초생활수급자 또는 차상위계층에게 소득 수준 및 주거형태에 따라 매월 장애수당을 지급합니...
# 표: ['구분', '장애수당', '장애수당']...
#
# 장애인연금 (페이지 242, 표 1개)
# 대상: 18세 이상의 장애인연금법상 중증장애인* 중 본인과 배우자의 소득인정액이 선정기준액 이하에 해당하는 자...
# 내용: 18세 이상의 중증장애인에게 장애인연금(기초급여, 부가급여)를 지원합니다. 월지급액은 43만 2,510원부터 시작하여 차등 지급됩니다. 65세 ...
# 표: ['구분', '18세 ~ 64세', '65세 이상**']...
#
# 여성장애인 출산비용 지원 (페이지 243, 표 0개)
# 대상: 출산(임신기간 4개월 이상 유산, 사산 포함)한 여성 장애인...
# 내용: 출산(유산, 사산 포함) 태아 1인 기준 120만 원 지급. 해산급여, 첫만남이용권과 중복지원 가능. 신청에 필요한 서류는 신청자 신분증(대리 ...
#
# 장애아 보육료 지원 (페이지 244, 표 1개)
# 대상: 장애인복지카드를 소지한 12세 이하의 미취학 장애아동, 장애소견이 있는 의사진단서 제출자(5세 이하 장애인 복지카드 미소지자), 특수교육대상자 ...
# 내용: 장애아 보육료 지원은 장애아동의 어린이집 보육료를 지원하는 프로그램으로, 3~5세 누리반, 장애아반 편성 아동은 월 58만 7,000원을 받으며...
# 표: ['대상', '지급액']...
#
# 발달장애인 가족휴식 지원 (페이지 245, 표 0개)
# 대상: 발달장애인(지적･자폐성 장애) 및 그 가족
# - 지적장애, 자폐성 장애를 부장애로 가진 경우도 포함
# - 자녀가 영유아(만 6세 미만)의 경우, 장...
# 내용: 발달장애인 가족휴식 지원은 발달장애인 및 그 가족을 대상으로 힐링캠프, 테마여행, 자율여행 등 다양한 휴양･치유 프로그램을 제공합니다. 휴식지원...
#
# 발달장애인 부모 상담 지원 (페이지 246, 표 0개)
# 대상: 발달장애인(지적･자폐성 장애) 자녀를 둔 부모 및 보호자...
# 내용: 발달장애인 부모 및 보호자에게 개별/집단 상담을 제공하며, 발달장애인 자녀를 양육 중인 부모에게 심리상담바우처(월 16만 원)을 12개월 동안 ...
#
# 장애아 방과후 보육료 지원 (페이지 247, 표 0개)
# 대상: 만 12세 이하 취학아동 중 방과후 어린이집을 일일 4시간 이상 이용하는 장애아동...
# 내용: 장애아 보육료의 50%(월 29만 3,000원) 지급. 장애아 보육료(취학 전)를 지원받는 아동. 만 12세 이하의 취학아동 중 장애아동(야간연...
#
# 특수교육대상자 치료지원 서비스 (페이지 248, 표 0개)
# 대상: 특수교육대상자 중 교육을 효율적으로 실시하기 위하여 치료지원을 필요로 하는 학생...
# 내용: 병･의원, 장애인복지관, 사설치료실 등에서 특수교육대상자가 필요로 하는 물리치료, 작업치료, 언어치료 등의 서비스를 이용할 수 있습니다. 보건복...
#
# 국립특수학교 및 국립부설학교 특수학급 지원 (페이지 249, 표 0개)
# 대상: 국립특수학교(급)에 재학 중인 특수교육대상 학생...
# 내용: 국립특수학교(급)에 재학 중인 특수교육대상 학생을 대상으로 신변처리, 급식, 교내외 활동, 등하교를 돕는 특수교육 지원인력 배치, 다양한 교육활...
#
# 장애인 정보화교육 (페이지 250, 표 1개)
# 대상: 「장애인 등에 대한 특수교육법」에 따른 특수교육대상자* 및 담당 교원
# * 시각장애, 청각장애, 지적장애, 지체장애, 정서･행동장애, 자폐성장애,...
# 내용: 전국 장애인 정보화교육기관에서 컴퓨터 기초, 인터넷 등 정보활용 능력 배양과 자격증 취득을 위한 정보화교육 실시(교재, 교육비 전액 무료), 정...
# 표: ['사이트명', '사이트 주소', '지원 내용']...
#
# 장애인 일자리 지원 (페이지 251, 표 1개)
# 대상: 18세 이상 미취업 등록장애인...
# 내용: 장애로 인해 직장을 갖기 어려운 장애인이 직업능력을 높여 공공기관 등에서 일할 수 있도록 지원...
# 표: ['구분', '지원대상', '지원내용']...
#
# 중증장애인 직업재활 지원 (페이지 252, 표 0개)
# 대상: 15세 이상 등록장애인 및 특수교육대상자...
# 내용: 중증장애인을 대상으로 '직업상담･평가 → 직업재활계획 수립 → 직업적응훈련 → 취업알선 → 취업 후 적응지원' 등의 일련의 직업재활서비스를 제공...
#
# 장애인직업재활시설 이용 (페이지 253, 표 1개)
# 대상: 작업능력이 있는 장애인, 작업능력이 낮은 장애인, 작업능력이 극히 낮은 장애인, 근로장애인 30명 이상(중증장애인 60% 이상 유지), 근로장애...
# 내용: 장애인직업재활시설은 근로사업장, 보호작업장, 직업적응훈련시설을 이용하여 일하기 어려운 장애인에게 특별히 준비된 작업환경에서 직업훈련을 받거나 직...
# 표: ['구분', '이용자 기준', '근로･임금 기준']...
#
# 중증장애인생산품 우선구매 (페이지 254, 표 0개)
# 대상: 장애인직업재활시설 등 중증장애인생산품 생산시설, 장애인복지시설 및 단체, 재가장애인, 장애인생산품을 구매하려는 일반국민...
# 내용: 중증장애인생산품 우선구매는 공공기관의 총 구매액 중 1.1% 우선구매 혜택을 제공하며, 장애인생산품 판매 지원, 신규품목 발굴, 판로개척 등을 ...
#
# 장애인 취업성공패키지 (페이지 255, 표 1개)
# 대상: 만 18세 이상 구직장애인(중위소득 60% 이하 저소득층 포함)...
# 내용: 장애인에게 성공적인 취업과 직업적응을 지원하기 위한 통합 취업지원프로그램으로, 상담을 통한 진로설계, 취업계획 수립(1단계), 구직역량 강화(2...
# 표: ['구분', '지원대상', '지원요건']...
#
# 중증장애인 근로지원인 (페이지 256, 표 0개)
# 대상: 중증장애인 근로자(장애인공무원 포함)...
# 내용: 핵심적인 업무 수행 능력을 보유하고 있으나 장애로 인해 부수적인 업무(서류대독, 물품이동, 의사소통 및 고객응대, 심리적응 등) 수행이 어려운 ...
#
# 장애인 신규 고용장려금 지원 (페이지 257, 표 1개)
# 대상: 2022.1.1. 이후 장애인을 신규로 고용하여 6개월 이상 고용을 유지한 소규모(5인 이상 50인 미만 상시고용) 사업주...
# 내용: 2022년 발생분까지: 경증남성 30만 원(180만 원), 경증여성 45만 원(270만 원), 중증남성 60만 원(360만 원), 중증여성 80...
# 표: ['해당연도', '구분', '지급단가(월)']...
#
# 중증장애인 지원고용(훈련수당) (페이지 258, 표 0개)
# 대상: 만 15세 이상 중증장애인이거나 고용지원 필요도 결정에 의해 ‘중점 고용지원 대상’으로 결정되는 장애인...
# 내용: 한국장애인고용공단에 구직등록을 한 대상자들을 대상으로 훈련기간 동안 사업체에서 직무습득 및 적응을 돕기 위한 지원을 제공합니다. 훈련준비금, 훈...
#
# 장애인 직업능력개발 운영(훈련수당) (페이지 259, 표 1개)
# 대상: 만 15세 이상으로 직업능력개발훈련을 희망하거나 필요로 하는 장애인 중 소정의 입학절차를 통과한 자...
# 내용: 장애인 직업능력개발 운영(훈련수당)은 월 최대 20만 원의 훈련참여수당을 제공하며, 교통비와 식비도 일부 지원합니다. 훈련기간은 6개월, 12개...
# 표: ['구분', '지원내용']...
#
# 근로장애인 전환지원 (페이지 260, 표 1개)
# 대상: 근로장애인...
# 내용: 근로장애인 전환지원 프로그램으로, 최저임금 적용제외인 근로자가 최저임금 이상 급여를 받는 사업장으로 전환 취업할 수 있도록 지원. 월 최대 30...
# 표: ['구분', '경증 장애인 (2020~2022년)', '경증 장애인 (2023년 이후)']...
#
# 장애인고용 시설장비 융자･무상지원 (페이지 261, 표 1개)
# 대상: 장애인을 고용하여 사업을 운영하고 있거나 운영하고자 하는 사업주...
# 내용: 장애인을 위한 작업시설, 부대시설, 편의시설의 설치･구입비를 사업주당 15억 원 한도로 대출하고 이자차액을 지원. 편의시설 설치, 통근용 승합자...
# 표: ['융자', '무상지원']...
#
# 장애인 표준사업장 설립 지원 (페이지 262, 표 0개)
# 대상: 장애인표준사업장을 설립, 운영하고자 하는 사업주(장애인직업재활시설 제외)...
# 내용: 장애인표준사업장 설립을 희망하는 사업주에게 작업시설, 부대시설, 편의시설, 장애인 출퇴근용 승합차 구입, 각종 인증취득 및 컨설팅 소요 비용 등...
#
# 근로지원비용 지원 (페이지 263, 표 0개)
# 대상: 중증장애인 근로자를 신규로 고용하거나, 직무 전환 또는 배치 전환 후 90일 이내 수급자격 인정 신청을 하고, 작업지도원을 선임하여 장애인 1명...
# 내용: 중증장애인 근로자를 고용하거나 전환 후 수급자격 인정 신청한 사업주에게 장애인 1인당 월 14만 원을 최대 3년간 지급. 작업지도자는 최대 5명...
#
# 보조공학기기 지원 (페이지 264, 표 1개)
# 대상: 장애인을 고용한 사업주 또는 고용하려는 사업주, 장애인근로자, 장애인공무원, 장애인인 사업주 (상시근로자 4인 이하 고용 사업주로, 지원 결정일...
# 내용: 장애인 1인당 1,500만 원(중증장애인 2,000만 원) 한도로 작업용 보조공학기기를 지원하며, 지원한도액을 초과하는 금액은 지원대상자가 부담...
# 표: ['구분', '지원액', '보조공학기기 제품 구입 및 대여가격(맞춤형 기기 포함)']...
#
# 장애인 창업점포 지원사업 (페이지 266, 표 0개)
# 대상: 장애인(국가유공자 중 상이자 포함) 예비창업자, 재창업자(업종전환 희망자) 및 초기창업자(3년 미만)...
# 내용: 장애인 창업교육을 이수한 장애인을 대상으로 임차보증금(최대 1억 3천만 원 한도 내, 최장 5년간) 지원. 지원업종은 서비스업, 도소매 및 유통...
#
# 장애인 창업육성 (페이지 267, 표 2개)
# 대상: 장애인(국가유공자 중 상이자 포함) 예비창업자 및 업종전환희망자 등...
# 내용: 장애유형･희망업종별 맞춤형 창업 교육 및 창업지원 연계 서비스를 제공하며, 창업 유형별･업종별 맞춤형 교육을 무상으로 제공합니다. 창업기초교육,...
# 표: ['교육과정', '내용', '지원대상']...
#
# 정보통신 보조기기 보급 (페이지 268, 표 1개)
# 대상: 등록장애인 및 상이등급 판정을 받은 국가유공자...
# 내용: 정보통신 보조기기 제품가격 기준 정부지원 80%(본인부담금 20%) 기초생활수급자, 차상위(장애인수당급여자) 등 경제적 여건으로 기기구입이 어려...
# 표: ['장애유형', '보조기기 지원 품목']...
#
# 장애인 의료비 지원 (페이지 269, 표 1개)
# 대상: 등록장애인 중 의료급여 2종 수급권자 및 차상위 본인부담경감대상자(만성질환자 및 만 18세 미만 아동 등)...
# 내용: 장애인 의료비 지원은 장애인에게만 지원되며, 의료기관 진료비 중 의료비 본인부담금(급여항목만 해당)을 전액 또는 일부 지원합니다. 외래의 경우 ...
# 표: ['구분', '1차 의료기관', '2, 3차 의료기관']...
#
# 장애인 건강보험료 경감 (페이지 270, 표 0개)
# 대상: 등록장애인...
# 내용: 건강보험료 및 장기요양보험료를 일정 비율로 경감하는 지원 제도입니다. 자동차 소유자의 경우 자동차분 건강보험료는 전액 면제되며, 소득과 재산 기...
#
# 장애인 보조기기 급여 (페이지 271, 표 0개)
# 대상: 건강보험(의료급여) 대상자 중 등록장애인...
# 내용: 건강보험 대상자와 의료급여 수급권자를 대상으로 전동휠체어, 의료용 스쿠터, 자세보조용구 등의 기준액, 고시액, 구입액 중 낮은 금액을 지원합니다...
#
# 장애정도 심사 검사비 지원 (페이지 272, 표 0개)
# 대상: 신규 장애인 등록 신청자 중 기초생활수급자(생계, 의료, 주거, 교육), 기존 등록장애인 중 재판정을 실시하는 기초생활수급자(생계, 의료, 주거...
# 내용: 장애정도 심사 검사비 지원은 장애인 등록 및 서비스 신청서, 영수증을 지참하여 읍면동 주민센터(행정복지센터)에 신청하면 가능합니다. 또한 보건복...
#
# 장애인 보조기기 교부 (페이지 273, 표 1개)
# 대상: 기초생활보장법상 생계, 의료, 주거, 교육급여 수급자 및 차상위계층인 지체･뇌병변･시각･청각･심장･호흡･언어･자폐성･지적 장애인...
# 내용: 장애인 보조기기 교부 프로그램은 44개 품목의 보조기구를 지원 금액 내에서 무료로 교부합니다. 시각, 심장, 청각, 지체･뇌병변 등 다양한 장애...
# 표: ['지원내용', '구분']...
#
# 언어발달 지원 (페이지 274, 표 0개)
# 대상: 부모(조손 가정일 경우 조부모) 중 어느 한쪽 (조)부모가 시각, 청각, 언어, 지적, 자폐성, 뇌병변 등록 장애인이며, 건강보험료 본인부담금 ...
# 내용: 언어발달 지원은 매월 16∼22만 원의 언어발달 지원 이용권(바우처)을 지급하며, 언어발달진단서비스, 언어재활서비스, 독서지도, 수화지도 등을 ...
#
# 발달재활서비스 (페이지 275, 표 0개)
# 대상: 18세 미만 장애아동(뇌병변, 지적, 자폐성, 언어, 청각, 시각) ※ 재학 중인 아동은 20세 미만까지 가능...
# 내용: 건강보험료 본인부담금 합산액이 기준 중위소득 180% 이하 가구에게 매월 17∼25만 원의 발달재활 서비스이용권(바우처)를 지급하며, 발달재활서...
#
# 지역장애인보건의료센터 (페이지 276, 표 0개)
# 대상: 관할 시도 내 거주하는 장애인 또는 손상이나 질병발생 후 완전한 회복이 어려워 일정기간 내 장애인이 될 것으로 예상되는 자...
# 내용: 지역장애인보건의료센터는 의료를 기반으로 보건의료 및 복지의 필요 서비스를 통합적으로 연계 및 제공하여 대상자의 지역사회 조기복귀를 지원합니다. ...
#
# 장애친화 건강검진 (페이지 277, 표 0개)
# 대상: 장애인에 국한되지 않으며, 노인 등 거동이 불편한 수검자 이용 가능. 중증장애인은 별도의 검진가산비용에 대해 검진기관 추가 지원....
# 내용: 유니버설 검진장비, 탈의실, 접수대 등 편의시설, 검진보조인력(수어통역사) 배치 등을 통해 장애인의 예방의료서비스 이용접근성을 보장. 중증장애인...
#
# 장애인 재활지원 사업 (페이지 278, 표 1개)
# 대상: 척수장애인, 중도시각장애인, 시각장애인, 장애인...
# 내용: 척수장애인에게는 재활훈련지원, 중도시각장애인에게는 재활지원과 사회적 적응 지원, 시각장애인에게는 음악재활센터 지원, 장애인에게는 보조견 지원이 ...
# 표: ['지원대상', '지원내용']...
#
# 장애인 활동지원 (페이지 279, 표 1개)
# 대상: 만 6세~만 65세 미만 등록 장애인 중 신체기능과 자립생활 능력 등을 평가한 서비스 지원 종합조사 결과 활동지원등급 판정을 받은 사람(종합점수...
# 내용: 장애인 활동지원 서비스는 활동지원급여(1~15등급)와 특별지원급여(출산, 자립준비, 보호자 일시 부재)를 제공합니다. 활동지원급여는 최소 100...
# 표: ['구분', '지원내용', '금액']...
#
# 성인 발달장애인 주간활동 서비스 (페이지 280, 표 0개)
# 대상: 18세 이상 성인발달장애인...
# 내용: 성인 발달장애인을 대상으로 월 132/176시간의 주간활동서비스 바우처를 제공하며, 발달장애인이 지역사회의 다양한 기관이나 장소를 이용하고 동료...
#
# 여성장애인 가사도우미 파견 (페이지 281, 표 0개)
# 대상: 저소득 가정의 등록 여성장애인...
# 내용: 여성장애인의 산전･산후관리, 자녀양육, 가사활동 등을 지원하기 위한 가사도우미 파견...
#
# 장애인 거주시설 이용 (페이지 282, 표 0개)
# 대상: 우선입소대상 : 장애인 중 기초생활수급자 및 부양자가 없거나 부양을 받을 수 없는 자로서 서비스지원 종합조사 기능제한(X1) 일정 점수 이상인 ...
# 내용: 우선입소대상은 기초생활수급자 및 부양자가 없거나 부양을 받을 수 없는 장애인으로, 일정 점수 이상인 경우 중증장애인거주시설, 독랍형주거서비스제공...
#
# 무료 법률구조 제도 (페이지 283, 표 0개)
# 대상: 중위소득 125%(4인 기준 762만2,216원) 이하인 등록장애인...
# 내용: 무료 법률구조 제도는 중위소득 125% 이하인 등록장애인을 대상으로 소송 시 법원에 소요되는 일체의 비용을 무료로 지원합니다. 이를 신청하기 위...
#
# 장애인 자동차 표지 발급 (페이지 284, 표 0개)
# 대상: 장애인, 주민등록상 거주를 같이하는 보호자* 명의로 등록되어 있고 장애인이 주로 사용하는 자동차 1대, 장애인복지시설 및 단체 명의의 자동차...
# 내용: 장애인의 보행상 장애 여부에 따라 장애인전용 주차구역을 이용할 수 있는 표지를 발급하여 장애인전용 주차구역에 주차할 수 있도록 지원합니다. 장애...
#
# 장애인 운전교육 사업 (페이지 285, 표 0개)
# 대상: 면허조건(E, F, G, H, I)을 부여 받은 지체, 뇌병변, 청각장애인(기초생활수급자는 면허조건 없어도 됨)으로 제1종 및 제2종 보통 면허...
# 내용: 국립재활원에서 운전교육 받기 어려운 장애인 중 운전보조기기가 장착된 차량이나 수어로 교육이 필요한 장애인에게 강사가 운전교육 차량으로 거주지까지...
#
# 장애인 건강주치의 시범사업 (페이지 286, 표 0개)
# 대상: 지체･뇌병변･시각･지적･정신･자폐성 중증장애인...
# 내용: 장애인 건강주치의 시범사업은 지체･뇌병변･시각･지적･정신･자폐성 중증장애인을 대상으로, 주치의를 선택하여 전반적 건강관리 또는 주장애관리를 지속...
#
# 장애인 전용 승용자동차에 대한 개별소비세 면제 (페이지 287, 표 0개)
# 대상: 등록 장애인* (* 국가유공 상이자 및 이와 유사한 사람으로서 근로능력이 없는 사람, 항시 치료를 요하는 중증환자 포함)...
# 내용: 장애의 정도가 심한 장애인 본인 명의로 구입하거나 장애인과 주민등록표 등에 의하여 세대를 함께 하는 것이 확인되는 배우자, 직계존비속, 형제자매...
#
# 장애인용 자동차에 대한 지방세 감면 (페이지 288, 표 0개)
# 대상: 등록 장애인* (국가유공 상이자 및 이와 유사한 사람으로서 근로능력이 없는 사람, 항시 치료를 요하는 중증환자 포함)...
# 내용: 장애인이 보철용･생업활동용으로 사용하기 위해 취득하는 자동차(1대로 한정)의 취득세와 자동차세 감면. 취득세 및 자동차세 면제대상 차량: 배기량...
#
# 장애인보조기기 부가가치세 영세율 적용 (페이지 289, 표 0개)
# 대상: 등록장애인...
# 내용: 장애인보조기기(의수족, 휠체어, 보청기 등)에 대한 부가가치세 부과율을 0%로 적용...
#
# 지역사회 복지시설 이용 지원 (페이지 290, 표 0개)
# 대상: 장애인...
# 내용: 지역사회 복지시설을 이용하고 싶을 때, 주변의 다양한 복지시설을 이용할 수 있습니다....
#
# 장애인 체육시설 (페이지 291, 표 0개)
# 대상: 등록장애인...
# 내용: 장애인의 체력증진 및 신체기능 회복을 위해 스포츠 활동을 지원하며, 해당 지역 장애인 체육시설 등을 이용할 수 있습니다....
#
# 장애예술 활성화 지원 사업 (페이지 292, 표 0개)
# 대상: 예비 장애예술인(단체), 장애예술인(단체), 비장애예술인(단체)...
# 내용: 장애예술 활성화 지원 사업은 장애예술 창･제작 활동, 교류활동, 향유활동, 유통 및 확산을 지원하는 사업입니다. 국가문화예술지원시스템(ncas....
#
# 장애인을 위한 요금감면제도 (페이지 293, 표 1개)
# 대상: 등록장애인, 장애인 복지시설, 장애인 복지단체...
# 내용: 장애인을 위한 요금 감면 제도로는 TV 수신료 전액 면제, 시내전화 통화료 월 50% 감면, 시외전화 통화료 월 3만 원 한도 50% 감면, 인...
# 표: ['내역', '지원대상', '지원내용']...
