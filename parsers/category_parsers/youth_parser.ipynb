# %% [markdown]
# ### 카테고리별 지원 파싱 (청소년청년지원)
# 청소년청년지원 (140~187페이지) 파싱

# %%
import os
import json
import time
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from pydantic import BaseModel, Field
import fitz

# 환경변수 로드
load_dotenv()
# Out:
# True

# %%
class TableData(BaseModel):
    columns: list = Field(description="표의 열 제목들")
    rows: list = Field(description="표의 행 데이터들")

class WelfareProgram(BaseModel):
    title: str = Field(description="복지 프로그램의 정확한 지원명")
    target: str = Field(description="지원 대상자")
    content: str = Field(description="지원 내용")
    method: str = Field(description="신청 방법")
    inquiry: str = Field(description="문의처")
    tables: list[TableData] = Field(description="표 데이터 구조")

# %%
def extract_page_text(pdf_path, page_num):
    """PDF 페이지에서 텍스트 추출"""
    doc = fitz.open(pdf_path)
    page = doc.load_page(page_num - 1)
    text = page.get_text("text")
    doc.close()
    return text

# %%
def parse_welfare_with_langchain(text, page_num):
    """랭체인을 사용하여 복지 프로그램 정보 파싱"""
    
    # LLM 초기화 (재시도 설정 추가)
    llm = ChatOpenAI(
        model="gpt-3.5-turbo",
        temperature=0,
        request_timeout=60,
        max_retries=3
    )
    
    # 출력 파서 설정
    parser = JsonOutputParser(pydantic_object=WelfareProgram)
    
    # 프롬프트 템플릿
    prompt = ChatPromptTemplate.from_messages([
        ("system", """청소년청년지원 문서 전용 파서입니다.

검증 로직:
1. "대상", "내용", "방법", "문의" 4개 필수 키워드 존재 확인
2. 키워드 중 하나라도 없으면 null 반환

제도명 추출 규칙:
- "나에게 힘이 되는 복지서비스"는 페이지 헤더이므로 제외
- "청소년·청년 지원"은 카테고리명이므로 제외
- 실제 제도명만 추출 (예: "청소년 방과후아카데미", "청년도약계좌", "청년내일채움공제")

표 처리 규칙:
1. content: 표 내용을 자연어로 요약하여 포함
2. tables: 표가 있으면 구조화된 데이터로 저장
   - columns: 실제 표의 열 제목을 정확히 추출 (예: ["구분", "지원내용", "금액"])
   - rows: 실제 표의 행 데이터를 정확히 추출 (예: [["청소년", "교육지원", "월 30만원"]])
   - 표의 실제 구조를 그대로 반영하여 저장
3. 표가 없으면 tables는 빈 배열

추출 최적화:
- 제도명: 실제 청소년청년지원제도명만
- 대상: 연령, 소득기준, 학력, 취업상태 등 구체적 조건
- 내용: 지원금액, 지원기간, 지원내용 (표 데이터 요약 포함)
- 방법: 신청기관, 온라인/오프라인 구분, 필요서류
- 문의: 콜센터, 웹사이트, 담당기관
- tables: 표가 있으면 실제 컬럼명과 데이터로 구조화하여 저장

{format_instructions}"""),

        ("human", """청소년청년지원 문서를 분석합니다.

1단계: 필수 키워드 확인
- "대상", "내용", "방법", "문의" 4개 키워드 모두 존재하는지 확인
- 하나라도 없으면 null 반환

2단계: 제도명 추출
- "나에게 힘이 되는 복지서비스" 제외
- "청소년·청년 지원" 제외
- 실제 청소년청년지원제도명만 추출

3단계: 정보 추출
- content: 표 내용을 자연어로 요약하여 포함
- tables: 표가 있으면 실제 컬럼명과 행 데이터를 정확히 추출하여 저장
- 각 키워드 바로 다음 내용을 정확히 추출

텍스트:
{text}
""")
    ])
    
    # 체인 구성
    chain = prompt | llm | parser
    
    # 재시도 로직
    for attempt in range(3):
        try:
            result = chain.invoke({
                "text": text,
                "format_instructions": parser.get_format_instructions()
            })
            
            if result is None:
                print(f"페이지 {page_num}: 필수 키워드 부족으로 건너뛰기")
                return None
            
            result["page"] = page_num
            result["category"] = "청소년청년지원"
            
            return result
        except Exception as e:
            print(f"파싱 시도 {attempt + 1}/3 실패 (페이지 {page_num}): {e}")
            if attempt < 2:
                time.sleep(2)  # 2초 대기 후 재시도
            else:
                return None

# %%
# 설정
pdf_path = "../../data/pdfs/[통합]+2025+나에게+힘이+되는+복지서비스.pdf"
target_pages = list(range(140, 188))  # 청소년청년지원 섹션 (140~187페이지)

welfare_programs = []

# %%
# 페이지별 파싱 실행
for i, page_num in enumerate(target_pages):
    print(f"페이지 {page_num} 파싱 중... ({i+1}/{len(target_pages)})")
    
    # 페이지 텍스트 추출
    page_text = extract_page_text(pdf_path, page_num)
    
    # 랭체인으로 파싱
    program = parse_welfare_with_langchain(page_text, page_num)
    
    if program:
        welfare_programs.append(program)
        table_count = len(program.get('tables', []))
        print(f"{program['title']} 추출 완료 (표 {table_count}개)")
    else:
        print(f"페이지 {page_num} 건너뛰기")
    
    # API 호출 간격 조절
    if i < len(target_pages) - 1:
        time.sleep(1)
# Out:
# 페이지 140 파싱 중... (1/48)
# 아동통합서비스 지원(드림스타트사업) 추출 완료 (표 0개)
# 페이지 141 파싱 중... (2/48)
# 가정위탁아동 지원 추출 완료 (표 1개)
# 페이지 142 파싱 중... (3/48)
# 학대피해아동 보호 및 지원 추출 완료 (표 0개)
# 페이지 143 파싱 중... (4/48)
# 경계선지능아동 맞춤형 사례관리서비스 추출 완료 (표 0개)
# 페이지 144 파싱 중... (5/48)
# 자립준비청년(보호종료아동) 자립수당 추출 완료 (표 0개)
# 페이지 145 파싱 중... (6/48)
# 자립지원 전담기관 운영 추출 완료 (표 1개)
# 페이지 146 파싱 중... (7/48)
# 청소년치료재활센터 추출 완료 (표 0개)
# 페이지 147 파싱 중... (8/48)
# 청소년동반자 프로그램 추출 완료 (표 1개)
# 페이지 148 파싱 중... (9/48)
# 학교 밖 청소년 건강검진 추출 완료 (표 1개)
# 페이지 149 파싱 중... (10/48)
# 위기청소년 특별지원 추출 완료 (표 1개)
# 페이지 150 파싱 중... (11/48)
# 청소년성문화센터 추출 완료 (표 0개)
# 페이지 151 파싱 중... (12/48)
# 청소년 인터넷･스마트폰 과의존 치유 지원 추출 완료 (표 0개)
# 페이지 152 파싱 중... (13/48)
# 위(Wee)프로젝트 추출 완료 (표 1개)
# 페이지 153 파싱 중... (14/48)
# 지역사회 청소년 통합지원체계(청소년안전망) 추출 완료 (표 0개)
# 페이지 154 파싱 중... (15/48)
# 청소년쉼터 추출 완료 (표 0개)
# 페이지 155 파싱 중... (16/48)
# 청소년자립지원관 추출 완료 (표 1개)
# 페이지 156 파싱 중... (17/48)
# 청소년의 조화로운 성장과 역량 강화를 지원하는 프로그램 추출 완료 (표 0개)
# 페이지 157 파싱 중... (18/48)
# 청소년활동진흥센터 추출 완료 (표 0개)
# 페이지 158 파싱 중... (19/48)
# 청소년활동 지원 추출 완료 (표 0개)
# 페이지 159 파싱 중... (20/48)
# 이주배경청소년 지원 추출 완료 (표 1개)
# 페이지 160 파싱 중... (21/48)
# 교육급여 추출 완료 (표 1개)
# 페이지 161 파싱 중... (22/48)
# 고교학비 지원 추출 완료 (표 0개)
# 페이지 162 파싱 중... (23/48)
# 초중고 학생 교육정보화 지원 추출 완료 (표 0개)
# 페이지 163 파싱 중... (24/48)
# 학교 우유급식 추출 완료 (표 0개)
# 페이지 164 파싱 중... (25/48)
# 여성청소년 생리용품 바우처 지원 추출 완료 (표 0개)
# 페이지 165 파싱 중... (26/48)
# 국민행복카드 추출 완료 (표 0개)
# 페이지 166 파싱 중... (27/48)
# HPV 국가예방접종 지원사업 추출 완료 (표 0개)
# 페이지 167 파싱 중... (28/48)
# 교육복지 우선지원사업 추출 완료 (표 0개)
# 페이지 168 파싱 중... (29/48)
# 복권기금 꿈사다리 장학사업 추출 완료 (표 1개)
# 페이지 169 파싱 중... (30/48)
# 우수고등학생 해외유학 장학금(드림장학금) 추출 완료 (표 1개)
# 페이지 170 파싱 중... (31/48)
# 고졸 후학습자 장학금(희망사다리Ⅱ유형) 추출 완료 (표 1개)
# 페이지 171 파싱 중... (32/48)
# 국가장학금 추출 완료 (표 1개)
# 페이지 172 파싱 중... (33/48)
# 이공계 우수학생 국가장학사업 추출 완료 (표 1개)
# 페이지 173 파싱 중... (34/48)
# 국가근로장학금 추출 완료 (표 0개)
# 페이지 174 파싱 중... (35/48)
# 예술체육 비전장학금 추출 완료 (표 0개)
# 페이지 175 파싱 중... (36/48)
# 인문100년 장학금 추출 완료 (표 1개)
# 페이지 176 파싱 중... (37/48)
# 대학생 청소년교육지원장학금 추출 완료 (표 0개)
# 페이지 177 파싱 중... (38/48)
# 푸른등대 기부장학사업 추출 완료 (표 0개)
# 페이지 178 파싱 중... (39/48)
# 중소기업 취업연계 장학사업(희망사다리Ⅰ유형) 추출 완료 (표 1개)
# 페이지 179 파싱 중... (40/48)
# 취업 후 상환 학자금대출 추출 완료 (표 1개)
# 페이지 180 파싱 중... (41/48)
# 취업 후 상환 학자금 대출 추출 완료 (표 0개)
# 페이지 181 파싱 중... (42/48)
# 일반 상환 학자금 대출 추출 완료 (표 0개)
# 페이지 182 파싱 중... (43/48)
# 농촌출신 대학생 학자금 융자사업 추출 완료 (표 0개)
# 페이지 183 파싱 중... (44/48)
# 심신장애인 학자금대출 채무면제 추출 완료 (표 0개)
# 페이지 184 파싱 중... (45/48)
# 경제적 배려대상자 지원 추출 완료 (표 0개)
# 페이지 185 파싱 중... (46/48)
# 병무청 청소년·청년 지원 프로그램 추출 완료 (표 0개)
# 페이지 186 파싱 중... (47/48)
# 병역이행안내-병역감면-생계유지 곤란사유 병역감면 추출 완료 (표 0개)
# 페이지 187 파싱 중... (48/48)
# 청년도약계좌 추출 완료 (표 0개)

# %%
# 결과 저장
os.makedirs("outputs", exist_ok=True)
output_path = "../../data/outputs/청소년청년지원_2025.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(welfare_programs, f, ensure_ascii=False, indent=2)

print(f"\n파싱 완료: {len(welfare_programs)}개 프로그램")
print(f"저장 위치: {output_path}")
# Out:
# 파싱 완료: 48개 프로그램
# 저장 위치: ../../data/outputs/청소년청년지원_2025.json

# %%
# 결과 미리보기 (타입 안정성 추가)
for program in welfare_programs:
    tables = program.get('tables', [])
    # tables가 dict로 들어오는 경우가 있어 리스트로 정규화
    if isinstance(tables, dict):
        tables = [tables]
    table_count = len(tables)

    title = program.get('title', '무제')
    page = program.get('page', '?')
    target = program.get('target') or ''
    content = program.get('content') or ''

    print(f"\n{title} (페이지 {page}, 표 {table_count}개)")
    print(f"대상: {target[:80]}{'...' if len(target) > 80 else ''}")
    print(f"내용: {content[:80]}{'...' if len(content) > 80 else ''}")

    if table_count > 0:
        first_table = tables[0]
        cols = first_table.get('columns') if isinstance(first_table, dict) else None
        if isinstance(cols, list):
            print(f"표: {cols[:3]}...")
        else:
            print("표: (컬럼 정보 없음)")
# Out:
# 아동통합서비스 지원(드림스타트사업) (페이지 140, 표 0개)
# 대상: 12세 이하(초등학생 이하)의 취약계층 아동 및 가족(임산부 포함)
# 내용: 아동통합서비스 지원(드림스타트사업)은 12세 이하(초등학생 이하)의 취약계층 아동 및 가족(임산부 포함)을 대상으로, 가정방문을 통해 조사한 양...
#
# 가정위탁아동 지원 (페이지 141, 표 1개)
# 대상: 친부모가 직접 양육할 수 없어 자격을 갖춘 위탁가정에서 보호하고 있는 아동, 전문가정위탁, 일반가정위탁, 일시가정위탁
# 내용: 가정위탁아동을 위한 양육보조금, 디딤씨앗통장, 심리치료비, 교통비, 상해보험료, 전문아동보호비, 아동용품구입비 등 다양한 지원이 제공됩니다.
# 표: ['구분', '지원내용']...
#
# 학대피해아동 보호 및 지원 (페이지 142, 표 0개)
# 대상: 만 18세 미만 학대피해아동 및 그 가족
# 내용: 학대피해아동 및 가족에 대한 상담, 심리치료, 교육서비스 제공, 재학대 발생방지를 위한 모니터링 등 사후관리, 학대피해아동 보호 및 숙식 제공,...
#
# 경계선지능아동 맞춤형 사례관리서비스 (페이지 143, 표 0개)
# 대상: 아동복지시설 보호아동 중 경계선지능으로 의심되거나 종합심리검사 결과 경계선지능으로 진단받은 아동
# 내용: 경계선지능아동을 위해 선별검사 비용을 지원하고 맞춤형 사례관리 서비스를 제공합니다. 선별검사는 지능검사, HTP, 문장완성검사 등으로 구성되어 ...
#
# 자립준비청년(보호종료아동) 자립수당 (페이지 144, 표 0개)
# 대상: 아동복지시설, 가정위탁 보호종료 아동 중 보호종료일을 기준으로 과거 2년 이상 연속하여 보호를 받은 자로서 다음 사항 중 어느 하나에 해당하는 ...
# 내용: 자립수당으로 월 50만 원을 지급합니다. 자립준비청년은 주소지 읍면동 주민센터(행정복지센터) 또는 복지누리집(www.bokjiro.go.kr)에...
#
# 자립지원 전담기관 운영 (페이지 145, 표 1개)
# 대상: 아동복지시설, 가정위탁 보호종료 5년 이내 자립준비청년
# 내용: 아동복지시설이나 가정위탁에서 보호종료된 5년 이내 자립준비청년을 대상으로 사후관리 및 자립지원통합서비스를 제공합니다. 사후관리 상담, 자립수준평...
# 표: ['구분', '지원내용']...
#
# 청소년치료재활센터 (페이지 146, 표 0개)
# 대상: 정서･행동에 어려움이 있는 청소년(만 9세~18세)
# 내용: 청소년치료재활센터는 정서･행동에 어려움이 있는 청소년을 대상으로 우울증, 불안장애, 학교부적응, 주의력결핍과잉행동장애(ADHD), 학대 및 학교...
#
# 청소년동반자 프로그램 (페이지 147, 표 1개)
# 대상: 다양한 위기를 겪고 있는 9~24세 청소년 (우울증, 자살위험, 가출, 비행, 인터넷 중독, 폭력(성･학교･가정) 피해, 학업중단)
# 내용: 청소년 상담 전문가가 위기상황 청소년을 직접 찾아가 상담하고, 청소년의 문제 유형과 개별 특성을 고려한 서비스 제공. 학교 밖 청소년 지원도 포...
# 표: ['대상', '내용', '방법']...
#
# 학교 밖 청소년 건강검진 (페이지 148, 표 1개)
# 대상: 9세 이상 18세 이하 학교 밖 청소년
# 내용: 학교 밖 청소년을 대상으로 건강검진을 실시하며, 검사항목은 혈액검사, 구강검진, 흉부 방사선 촬영 등이 포함됩니다. 건강검진 비용은 전액 지원되...
# 표: ['구분', '검사항목 및 방법']...
#
# 위기청소년 특별지원 (페이지 149, 표 1개)
# 대상: 9세 이상 24세 이하 위기 청소년
# - 보호자가 없거나 실질적으로 보호자의 보호를 받지 못하는 청소년
# - 학교 밖 청소년
# - 비행･일탈 예방을 ...
# 내용: 위기청소년을 대상으로 의복･음식물 및 연료비, 숙식 제공, 진찰･검사, 약제･치료재료의 지급, 학교 입학금 및 수업료 등 다양한 지원을 제공합니...
# 표: ['지원종류', '지원내용', '지원금액']...
#
# 청소년성문화센터 (페이지 150, 표 0개)
# 대상: 아동･청소년, 부모 및 교사 등
# 내용: 청소년성문화센터는 아동･청소년을 대상으로 연령별, 대상별 맞춤형 성교육 및 성범죄 예방교육을 실시하고, 아동･청소년 관련 시설, 기관, 학교 등...
#
# 청소년 인터넷･스마트폰 과의존 치유 지원 (페이지 151, 표 0개)
# 대상: 만 19세 미만 청소년, 학령전환기 청소년(초1, 초4, 중1, 고1)
# 내용: 청소년 인터넷･스마트폰 과의존 상담, 치료연계 등 지원. 상담 및 치유프로그램으로는 개인상담, 집단상담, 추가심리검사, 인터넷･스마트폰 치유캠프...
#
# 위(Wee)프로젝트 (페이지 152, 표 1개)
# 대상: 일반학생 및 심리･정서적 문제 등으로 학교부적응을 겪고 있는 학생, 학생과 관련된 상담을 희망하는 보호자 및 교사
# 내용: 위(Wee)프로젝트는 학교적응 지원 및 학업중단 예방을 위한 심리검사, 상담, 체험 프로그램 등을 제공합니다. 구체적인 상담 지원 내용은 해당 ...
# 표: ['구분', '지원내용']...
#
# 지역사회 청소년 통합지원체계(청소년안전망) (페이지 153, 표 0개)
# 대상: 만 9세~24세 위기청소년 및 가족
# 내용: 위기청소년이 가정, 학교 및 사회로 안전하게 돌아갈 수 있도록 상담･보호･교육･자립 등 맞춤형 서비스 제공
#
# 청소년쉼터 (페이지 154, 표 0개)
# 대상: 가정 내 갈등･학대･폭력･방임, 가정해체, 가출 등의 사유로 보호자로부터 이탈된 청소년으로서 사회적 보호 및 지원이 필요한 청소년
# 내용: 청소년쉼터는 가정 내 갈등, 학대, 폭력, 방임, 가정해체, 가출 등의 사유로 보호자로부터 이탈된 청소년을 위해 제공되는 서비스로, 부채 및 신...
#
# 청소년자립지원관 (페이지 155, 표 1개)
# 대상: 시설(청소년쉼터, 청소년회복지원시설) 퇴소 후 추가적인 자립지원이 필요한 청소년 또는 가정의 지원을 받지 못하여 자립 지원이 필요한 청소년
# 내용: 청소년자립지원관은 퇴소 후 독립생활이 가능하도록 일상생활, 학업, 취업 및 주거 등 자립 목적의 사례관리를 통해 지도 및 지원합니다. 지원 기간...
# 표: []...
#
# 청소년의 조화로운 성장과 역량 강화를 지원하는 프로그램 (페이지 156, 표 0개)
# 대상: 청소년
# 내용: 청소년의 조화로운 성장과 역량 강화를 지원하기 위해 국제교류, 문화체험 등 다양한 활동에 참여할 수 있는 기회를 제공합니다.
#
# 청소년활동진흥센터 (페이지 157, 표 0개)
# 대상: 청소년 및 청년
# 내용: 청소년활동진흥센터는 전문화된 업무를 통해 센터의 조직과 인력의 전문성을 제고하고, 네트워크를 구축하고 운영하는 업무를 수행합니다.
#
# 청소년활동 지원 (페이지 158, 표 0개)
# 대상: 대한민국 청소년 및 법인･시설･단체
# 내용: 우수 청소년 활동 프로그램을 공모하여 지원하고, 국립수련시설에서 특별한 청소년 활동을 누릴 수 있습니다.
#
# 이주배경청소년 지원 (페이지 159, 표 1개)
# 대상: 9~24세 이주배경 청소년 (다문화가정 청소년, 중도입국 청소년, 외국인가정 청소년, 북한이탈 청소년 등)
# 내용: 이주배경청소년을 위한 레인보우스쿨 운영, 사회적응지원, 상담지원 및 상담환경 조성 등의 프로그램을 제공합니다. 레인보우스쿨은 전국 13개소로 운...
# 표: ['구분', '지원내용']...
#
# 교육급여 (페이지 160, 표 1개)
# 대상: 소득인정액이 기준 중위소득 50% 이하 가구의 자녀
# 내용: 교육활동지원비, 교과서비, 입학금 및 수업료를 지원합니다. 초등학생은 487,000원, 중학생은 679,000원, 고등학생은 768,000원을 ...
# 표: ['구분', '교육활동지원비', '교과서']...
#
# 고교학비 지원 (페이지 161, 표 0개)
# 대상: 기초생활수급자, 한부모가족, 차상위계층 등 저소득가구의 고등학교 자녀
# 내용: 고등학교 입학금, 수업료, 학교운영지원비 지원. 무상교육이 적용되는 고등학교 제외. 시도교육청의 기준에 따라 지원 대상 범위 상이.
#
# 초중고 학생 교육정보화 지원 (페이지 162, 표 0개)
# 대상: 기초생활수급자, 한부모가족, 차상위계층 등 저소득가구의 초중고학생 자녀
# 내용: 기초생활수급자, 한부모가족, 차상위계층 등 저소득가구의 초중고학생 자녀를 대상으로 가구당 컴퓨터 1대와 가구당 인터넷통신비 월 1만 7,600원...
#
# 학교 우유급식 (페이지 163, 표 0개)
# 대상: 재학중인 학생 중 국민기초생활 수급자, 차상위계층, 한부모 가족, 특수교육대상자, 교육비지원대상자, 국가유공자 자녀
# 내용: 학기중･방학중 우유 지원(연간 250일 내외, 530원/개 이내). 결식 우려가 있는 18세 미만 아동에게 단체급식소, 일반음식점 이용, 도시락...
#
# 여성청소년 생리용품 바우처 지원 (페이지 164, 표 0개)
# 대상: 9~24세 여성청소년
# 내용: 기초생활보장급여(생계･의료･주거･교육)수급자, 차상위계층, 한부모가족 지원 대상 가구의 9~24세 여성청소년이 생리용품을 구입할 수 있는 월 1...
#
# 국민행복카드 (페이지 165, 표 0개)
# 대상: 청소년 및 부모 등 법정대리인
# 내용: 국민행복카드는 청소년 또는 부모 등 법정대리인 명의로 발급 가능하며, 생리용품 바우처를 통해 생리용품을 구매할 수 있습니다. 생리용품 바우처 사...
#
# HPV 국가예방접종 지원사업 (페이지 166, 표 0개)
# 대상: 12~17세 여성 청소년(2007.1.1.~2013.12.31. 출생자), 18~26세 저소득층 여성(1998.1.1.~2006.12.31. 출...
# 내용: HPV 국가예방접종 지원사업은 12~26세 여성을 대상으로 하는 HPV 예방접종 프로그램으로, HPV 2가 백신과 HPV 4가 백신을 지원하며,...
#
# 교육복지 우선지원사업 (페이지 167, 표 0개)
# 대상: 교육급여 수급권자, 법정 차상위계층의 자녀, 법정 한부모가족의 자녀, 북한이탈주민의 자녀, 다문화가정의 자녀, 특수교육대상자, 기타 교육감이 정...
# 내용: 교육복지 우선지원사업은 학습, 문화･체험, 심리･정서, 보육, 복지 등 종합적인 교육복지 프로그램을 제공합니다. 지원대상 학생이 일정 수 이상인...
#
# 복권기금 꿈사다리 장학사업 (페이지 168, 표 1개)
# 대상: 국내 초･중･고등학교 재학생 중 역량과 잠재력을 갖춘 저소득층 가정 혹은 긴급구난사유에 해당하는 학생
# 내용: 매월 학업장려금(15~45만 원)을 장학금 카드로 지급하며, 멘토링 및 맞춤형 컨설팅, 심리 상담 등 다양한 교육프로그램을 지원합니다. 2025...
# 표: ['구분', '학업장려비', '교육프로그램']...
#
# 우수고등학생 해외유학 장학금(드림장학금) (페이지 169, 표 1개)
# 대상: 국내 고교 2, 3학년 재학자 중 해외대학 입학을 희망하는 저소득층(기초생활수급자, 차상위계층) 성적 우수 학생, 2026년 2월 또는 2027...
# 내용: 우수 고등학생을 대상으로 하는 해외유학 장학금으로, 성적 우수한 학생을 선발하며, 지원내용은 국내장학생과 해외장학생으로 나뉘어 각각 학업장려비 ...
# 표: ['구분', '지원내용']...
#
# 고졸 후학습자 장학금(희망사다리Ⅱ유형) (페이지 170, 표 1개)
# 대상: 최종학력이 고졸이며 현재 지원대상기업에 재직하고 있는 대학교 재학생 (일부 전문학사 취득자 지원 가능)
# 내용: 고졸 후학습자를 대상으로 중소･중견기업, 대기업, 비영리기관에서 재직하고 있는 대학교 재학생을 지원하는 장학금 프로그램입니다. 재직 경력, 성적...
# 표: ['구분', '연령', '출신고교']...
#
# 국가장학금 (페이지 171, 표 1개)
# 대상: 국내 대학에 재학 중인 학자금지원 대학생, 다자녀(자녀 셋 이상) 가구의 대학생(미혼이며 입학 당시 만 39세 이하)
# 내용: 국가장학금은 국내 대학에 재학 중인 학자금지원 대학생과 다자녀(자녀 셋 이상) 가구의 대학생을 대상으로 학자금을 지원합니다. 국가장학금에는 I유...
# 표: ['구분', '지원대상', '지원금액']...
#
# 이공계 우수학생 국가장학사업 (페이지 172, 표 1개)
# 대상: 대통령과학장학금, 국가우수장학금(이공계), 대학원대통령과학장학금을 지원받는 대상자
# 내용: 이공계 우수학생 국가장학사업은 대통령과학장학금, 국가우수장학금(이공계), 대학원대통령과학장학금을 통해 국내 및 해외 대학에 재학 중이거나 입학 ...
# 표: ['구분', '지원내용']...
#
# 국가근로장학금 (페이지 173, 표 0개)
# 대상: 재학 중인 학생 중, 아래의 성적 및 소득 요건을 모두 충족한 학생
# 내용: 국가근로장학금은 매월 근로시간당 장학금을 지급하며, 시급단가는 교내근로 10,030원, 교외근로 12,430원입니다. 최대 근로시간은 1일 8시...
#
# 예술체육 비전장학금 (페이지 174, 표 0개)
# 대상: 국내 4년제 대학의 예술 및 체육계열학과(부) 1,3학년 재학생
# 내용: 예술체육 비전장학금은 1학년 ‘전공탐색(Ⅰ, Ⅱ) 유형’과 3학년 ‘전공확립(Ⅰ, Ⅱ) 유형’으로 구분되며, 등록금 및 생활비를 지원합니다. 등...
#
# 인문100년 장학금 (페이지 175, 표 1개)
# 대상: 국내 4년제 대학의 인문사회계열 학과(부) 1, 3학년 재학생
# 내용: 인문100년 장학금은 1학년 ‘전공탐색(Ⅰ, Ⅱ) 유형’과 3학년 ‘전공확립(Ⅰ, Ⅱ) 유형’으로 구분되어 지원 대상을 선발합니다. 지원내용으로...
# 표: ['구분', '지원내용']...
#
# 대학생 청소년교육지원장학금 (페이지 176, 표 0개)
# 대상: 사업 참여대학에 재학중인 학생 중, 아래의 성적 요건을 충족한 학생 (성적 C0학점(70/100점) 이상)
# 내용: 대학생 청소년교육지원장학금은 대학에 재학 중인 학생 중 성적 요건을 충족한 경우 매월 활동시간당 장학금을 지급합니다. 시간당 단가는 12,430...
#
# 푸른등대 기부장학사업 (페이지 177, 표 0개)
# 대상: 국내 4년제 및 전문 대학교 재학생 중 기부처별 신청자격을 충족하는 자
# 내용: 푸른등대 기부장학사업은 국내 4년제 및 전문 대학교 재학생 중 기부처별 신청자격을 충족하는 자를 대상으로 합니다. 생활비지원은 매학기 신규 장학...
#
# 중소기업 취업연계 장학사업(희망사다리Ⅰ유형) (페이지 178, 표 1개)
# 대상: 중소기업 취업 및 창업을 희망하는 학부* 재학생
# * 일반대 3학년 이상, 전문대 2학년 이상. 단, 원격대학(방송통신대학 및 사이버대학 등)은 ...
# 내용: 중소기업 취업 및 창업을 희망하는 학부 재학생을 대상으로 하는 장학사업으로, 학기당 등록금 전액 지원 및 학기당 200만 원의 취･창업지원금을 ...
# 표: ['구분', '지원내용', '금액']...
#
# 취업 후 상환 학자금대출 (페이지 179, 표 1개)
# 대상: 협약 체결 대학 학부생, 협약 체결 대학 대학원생 및 전문대학의 전문기술석사 이수 중인 학생 (재학 및 입학･복학 예정인 대한민국 국민, 만 3...
# 내용: 취업 후 상환 학자금대출은 교육부 또는 한국장학재단과의 협약을 통해 국내 고등교육기관의 학부생, 대학원생, 전문대학의 전문기술석사 학생을 대상으...
# 표: ['구분', '대상', '연령']...
#
# 취업 후 상환 학자금 대출 (페이지 180, 표 0개)
# 대상: 학자금지원 9분위 이하 및 생활비 대출 대상
# 내용: 취업 후 상환 학자금 대출은 학자금지원 9분위 이하인 대학생 및 생활비 대출 대상인 8분위 이하 또는 9분위 중 긴급생계곤란자를 대상으로 합니다...
#
# 일반 상환 학자금 대출 (페이지 181, 표 0개)
# 대상: 국내 대학 학부생, 대학원생 및 전문기술석사 이수중인 학생, 학점은행제 교육훈련기관의 평가인정 학습과정 학습자 (만 55세 이하, 직전학기 성적...
# 내용: 일반 상환 학자금 대출은 국내 대학 학부생, 대학원생 및 전문기술석사 이수중인 학생 등을 대상으로 하며, 대출금리는 1.7%로 고정되어 있습니다...
#
# 농촌출신 대학생 학자금 융자사업 (페이지 182, 표 0개)
# 대상: 농어촌지역에 주민등록 주소를 두고 6개월(180일) 이상 거주하고 있거나 농어업에 종사하고 있는 학부모(보호자)의 자녀(대학생) 또는 농어업에 ...
# 내용: 농촌출신 대학생 학자금 융자사업은 농어촌지역에 거주하거나 농어업에 종사하는 대학생 및 학부모(보호자)의 자녀를 대상으로 학자금 지원을 제공합니다...
#
# 심신장애인 학자금대출 채무면제 (페이지 183, 표 0개)
# 대상: 심신장애로 인해 학자금대출을 상환할 수 없는 자
# 내용: 한국장학재단에서 학자금대출을 받은 후 심신장애로 인해 학자금대출을 상환할 수 없게 된 자 대상. 소득 조건으로 채무자 본인의 소득인정액이 기준중...
#
# 경제적 배려대상자 지원 (페이지 184, 표 0개)
# 대상: 기초생활수급자, 차상위계층*, 한부모가족지원대상자
# * 차상위자활, 차상위장애, 차상위본인부담경감, 차상위계층확인서 발급대상자
# 내용: 경제적, 신체적 어려움 또는 생계 곤란 등으로 발생할 수 있는 병역 관련 문제를 해소할 수 있도록 지원합니다. 모집병에 지원하는 현역대상에 가산...
#
# 병무청 청소년·청년 지원 프로그램 (페이지 185, 표 0개)
# 대상: 병무청에 소속된 청소년 및 청년
# 내용: 병무청에서는 청소년 및 청년을 대상으로 다양한 지원 프로그램을 운영하고 있습니다. 이 프로그램은 현역병 입영일자나 희망시기를 반영하여 매년 1~...
#
# 병역이행안내-병역감면-생계유지 곤란사유 병역감면 (페이지 186, 표 0개)
# 대상: 본인이 아니면 가족의 생계를 유지할 수 없는 현역병 입영통지 된 사람과 현역병으로 복무중인 사람, 사회복무요원 소집 대상자와 사회복무요원, 대체...
# 내용: 병역감면은 가족의 부양비, 재산액, 월수입액이 생계곤란 병역감면 기준에 모두 해당될 때 병역감면처분을 받을 수 있습니다. 대체복무요원은 소집면제...
#
# 청년도약계좌 (페이지 187, 표 0개)
# 대상: 신규 가입일 기준 만 19세 ~ 34세 이하인 청년 (병역이행기간 최대 6년 추가 인정), 직전과세기간의 총급여액이 7,500만 원 이하이며, ...
# 내용: 청년의 중장기 자산형성 지원을 위한 정책형 금융상품으로, 만기 5년 동안 매월 70만 원 한도 내에서 자유롭게 납입 가능한 정부지원형 적금상품
