# %% [markdown]
# ### 카테고리별 지원 파싱 (생계지원)
# 생계지원 (22~55페이지) 파싱

# %%
import os
import json
import time
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from pydantic import BaseModel, Field
import fitz

load_dotenv()
# Out:
# True

# %%
class TableData(BaseModel):
    columns: list = Field(description="표의 열 제목들")
    rows: list = Field(description="표의 행 데이터들")

class WelfareProgram(BaseModel):
    title: str = Field(description="복지 프로그램의 정확한 지원명")
    target: str = Field(description="지원 대상자")
    content: str = Field(description="지원 내용")
    method: str = Field(description="신청 방법")
    inquiry: str = Field(description="문의처")
    tables: list[TableData] = Field(description="표 데이터 구조")

# %%
def extract_page_text(pdf_path, page_num):
    doc = fitz.open(pdf_path)
    page = doc.load_page(page_num - 1)
    text = page.get_text("text")
    doc.close()
    return text

# %%
def parse_livelihood_support(text, page_num):
    llm = ChatOpenAI(
        model="gpt-3.5-turbo",
        temperature=0,
        request_timeout=60,
        max_retries=3
    )
    
    parser = JsonOutputParser(pydantic_object=WelfareProgram)
    
    prompt = ChatPromptTemplate.from_messages([
        ("system", """생계지원 문서 전용 파서입니다.

검증 로직:
1. "대상", "내용", "방법", "문의" 4개 필수 키워드 존재 확인
2. 키워드 중 하나라도 없으면 null 반환

제도명 추출 규칙:
- "나에게 힘이 되는 복지서비스"는 페이지 헤더이므로 제외
- "생계 지원"은 카테고리명이므로 제외
- 실제 제도명만 추출 (예: "기초생활보장제도", "차상위계층 지원", "긴급복지지원")

표 처리 규칙:
1. content: 표 내용을 자연어로 요약하여 포함
2. tables: 표가 있으면 구조화된 데이터로 저장
   - columns: 실제 표의 열 제목을 정확히 추출 (예: ["가구규모", "생계급여", "의료급여"])
   - rows: 실제 표의 행 데이터를 정확히 추출 (예: [["1인", "76만원", "1종"]])
   - 표의 실제 구조를 그대로 반영하여 저장
3. 표가 없으면 tables는 빈 배열

추출 최적화:
- 제도명: 실제 생계지원제도명만
- 대상: 소득기준, 재산기준, 가구구성 등 구체적 조건
- 내용: 지원금액, 지원기간, 지원내용 (표 데이터 요약 포함)
- 방법: 신청기관, 온라인/오프라인 구분, 필요서류
- 문의: 콜센터, 웹사이트, 담당기관
- tables: 표가 있으면 실제 컬럼명과 데이터로 구조화하여 저장

{format_instructions}"""),

        ("human", """생계지원 문서를 분석합니다.

1단계: 필수 키워드 확인
- "대상", "내용", "방법", "문의" 4개 키워드 모두 존재하는지 확인
- 하나라도 없으면 null 반환

2단계: 제도명 추출
- "나에게 힘이 되는 복지서비스" 제외
- "생계 지원" 제외
- 실제 생계지원제도명만 추출

3단계: 정보 추출
- content: 표 내용을 자연어로 요약하여 포함
- tables: 표가 있으면 실제 컬럼명과 행 데이터를 정확히 추출하여 저장
- 각 키워드 바로 다음 내용을 정확히 추출

텍스트:
{text}
""")
    ])
    
    chain = prompt | llm | parser
    
    for attempt in range(3):
        try:
            result = chain.invoke({
                "text": text,
                "format_instructions": parser.get_format_instructions()
            })
            
            if result is None:
                print(f"페이지 {page_num}: 필수 키워드 부족으로 건너뛰기")
                return None
            
            result["page"] = page_num
            result["category"] = "생계지원"
            
            return result
        except Exception as e:
            print(f"파싱 시도 {attempt + 1}/3 실패 (페이지 {page_num}): {e}")
            if attempt < 2:
                time.sleep(2)
            else:
                return None

# %%
# 실행
pdf_path = "../../data/pdfs/[통합]+2025+나에게+힘이+되는+복지서비스.pdf"
target_pages = list(range(22, 56))  # 생계지원 섹션 (22~55페이지)
livelihood_programs = []

for i, page_num in enumerate(target_pages):
    print(f"페이지 {page_num} 파싱 중... ({i+1}/{len(target_pages)})")
    
    page_text = extract_page_text(pdf_path, page_num)
    program = parse_livelihood_support(page_text, page_num)
    
    if program:
        livelihood_programs.append(program)
        table_count = len(program.get('tables', []))
        print(f"{program['title']} 추출 완료 (표 {table_count}개)")
    else:
        print(f"페이지 {page_num} 건너뛰기")
    
    if i < len(target_pages) - 1:
        time.sleep(1)
# Out:
# 페이지 22 파싱 중... (1/34)
# 기초생활보장제도 추출 완료 (표 1개)
# 페이지 23 파싱 중... (2/34)
# 부채･신용정보개선 추출 완료 (표 0개)
# 페이지 24 파싱 중... (3/34)
# 기초생활수급자를 위한 요금감면제도 추출 완료 (표 1개)
# 페이지 25 파싱 중... (4/34)
# 긴급복지 지원제도 추출 완료 (표 0개)
# 페이지 26 파싱 중... (5/34)
# 긴급복지지원 추출 완료 (표 1개)
# 페이지 27 파싱 중... (6/34)
# 온가족보듬사업 추출 완료 (표 1개)
# 페이지 28 파싱 중... (7/34)
# 긴급돌봄 지원사업 추출 완료 (표 1개)
# 페이지 29 파싱 중... (8/34)
# 생계 지원 추출 완료 (표 1개)
# 페이지 30 파싱 중... (9/34)
# 상병수당 지원 추출 완료 (표 1개)
# 페이지 31 파싱 중... (10/34)
# 생계지원 추출 완료 (표 0개)
# 페이지 32 파싱 중... (11/34)
# 행복주택 공급 추출 완료 (표 0개)
# 페이지 33 파싱 중... (12/34)
# 행복주택 생계지원 추출 완료 (표 0개)
# 페이지 34 파싱 중... (13/34)
# 분양전환 공공임대주택 공급 추출 완료 (표 0개)
# 페이지 35 파싱 중... (14/34)
# 공공주택 분양전환 지원 추출 완료 (표 1개)
# 페이지 36 파싱 중... (15/34)
# 매입임대주택 지원 추출 완료 (표 0개)
# 페이지 37 파싱 중... (16/34)
# 다가구주택･다세대·연립주택 매입임대 추출 완료 (표 1개)
# 페이지 38 파싱 중... (17/34)
# 전세임대 지원 프로그램 추출 완료 (표 1개)
# 페이지 39 파싱 중... (18/34)
# 전세임대 지원 프로그램 추출 완료 (표 1개)
# 페이지 40 파싱 중... (19/34)
# 주거취약계층 주거지원 추출 완료 (표 0개)
# 페이지 41 파싱 중... (20/34)
# 긴급 주거지원 추출 완료 (표 0개)
# 페이지 42 파싱 중... (21/34)
# 주거급여(맞춤형급여) 추출 완료 (표 1개)
# 페이지 43 파싱 중... (22/34)
# 슬레이트 처리 지원 추출 완료 (표 0개)
# 페이지 44 파싱 중... (23/34)
# 고효율조명기기 무상교체 지원 추출 완료 (표 0개)
# 페이지 45 파싱 중... (24/34)
# 에너지바우처 추출 완료 (표 0개)
# 페이지 46 파싱 중... (25/34)
# 사회취약계층 환경성질환 예방사업 추출 완료 (표 0개)
# 페이지 47 파싱 중... (26/34)
# 저소득층 에너지효율 개선 추출 완료 (표 0개)
# 페이지 48 파싱 중... (27/34)
# 전기요금 복지할인 대상 취약계층 고효율가전 구매지원 추출 완료 (표 0개)
# 페이지 49 파싱 중... (28/34)
# 주거안정자금지원 추출 완료 (표 0개)
# 페이지 50 파싱 중... (29/34)
# 버팀목 전세자금 대출 추출 완료 (표 0개)
# 페이지 51 파싱 중... (30/34)
# 주거안정 월세대출 추출 완료 (표 0개)
# 페이지 52 파싱 중... (31/34)
# 전세금안심대출보증 추출 완료 (표 0개)
# 페이지 53 파싱 중... (32/34)
# 국민행복기금 채무조정 추출 완료 (표 0개)
# 페이지 54 파싱 중... (33/34)
# 신용회복위원회 개인채무조정 추출 완료 (표 1개)
# 페이지 55 파싱 중... (34/34)
# 생계지원 추출 완료 (표 1개)

# %%
# 결과 저장
os.makedirs("outputs", exist_ok=True)
output_path = "../../data/outputs/생계지원_2025.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(livelihood_programs, f, ensure_ascii=False, indent=2)

print(f"\n파싱 완료: {len(livelihood_programs)}개 프로그램")
print(f"저장 위치: {output_path}")
# Out:
# 파싱 완료: 34개 프로그램
# 저장 위치: ../../data/outputs/생계지원_2025.json

# %%
# 결과 미리보기
for program in livelihood_programs:
    table_count = len(program.get('tables', []))
    print(f"\n{program['title']} (페이지 {program['page']}, 표 {table_count}개)")
    print(f"대상: {program['target'][:80]}...")
    print(f"내용: {program['content'][:80]}...")
    if table_count > 0:
        print(f"표: {program['tables'][0]['columns'][:3]}...")
# Out:
# 기초생활보장제도 (페이지 22, 표 1개)
# 대상: 소득인정액 기준, 부양의무자 기준을 충족하는 저소득층 수급권자...
# 내용: 국민기초생활보장법에 따른 국민기초생활보장제도는 소득 및 부양의무자 기준을 충족하는 저소득층에게 생계, 의료, 주거, 교육급여를 통해 최저 생활을...
# 표: ['구분', '1차(의원)', '2차(병원)']...
#
# 부채･신용정보개선 (페이지 23, 표 0개)
# 대상: 생계급여, 의료급여, 주거급여 수급자...
# 내용: 해산 급여: 출산(예정)한 경우 아이 1명당 70만 원(쌍둥이는 140만 원) 지급. 장제 급여: 사망한 경우 장례를 치르는 사람에게 사망자 1...
#
# 기초생활수급자를 위한 요금감면제도 (페이지 24, 표 1개)
# 대상: 생계급여, 의료급여 수급자 / 주거급여, 교육급여 수급자 / 각종 공공요금 수급자...
# 내용: 기초생활수급자를 위한 요금감면제도는 통신요금, 주거급여·교육급여, 각종 공공요금 등 다양한 분야에서 지원을 제공합니다. 통신요금 감면은 유선전화...
# 표: ['지원내용', '생계급여·의료급여', '주거급여·교육급여']...
#
# 긴급복지 지원제도 (페이지 25, 표 0개)
# 대상: 생계유지가 곤란한 저소득층으로 아래 위기사유와 소득･재산 기준을 충족하는 가구...
# 내용: 긴급복지 지원제도는 주요 위기 상황으로 인해 생계유지가 어려운 분들에게 생활비, 의료비, 주거비 등을 지원하는 제도입니다. 지원 대상은 주요 위...
#
# 긴급복지지원 (페이지 26, 표 1개)
# 대상: 긴급적인 생계비, 의료비, 주거비, 교육비 등을 필요로 하는 가구...
# 내용: 긴급적인 생계비, 의료비, 주거비, 교육비 등을 지원합니다. 생계유지비, 의료, 주거, 사회복지, 교육, 연료비, 해산비, 장제비, 전기요금 등...
# 표: ['구분', '지원내용', '지원금액']...
#
# 온가족보듬사업 (페이지 27, 표 1개)
# 대상: 한부모가족, 다문화가족, 1인 가구, 노부모 부양가족, 손자녀 돌봄 조부모, 청소년(한)부모 등 가족기능 회복 및 역량 강화를 희망하는 취약가족...
# 내용: 온가족보듬사업은 전국 가족센터를 통해 가족상담, 사례관리 기반 맞춤형 가족서비스를 지원합니다. 주요 내용으로는 가족상담, 사례관리, 교육·문화프...
# 표: ['구분', '주요내용']...
#
# 긴급돌봄 지원사업 (페이지 28, 표 1개)
# 대상: 위기 상황이 발생한 경우로 한시적 지원으로 돌봄 공백을 해소할 수 있는 경우...
# 내용: 긴급돌봄 지원사업은 위기 상황이 발생한 경우로 한시적 지원으로 돌봄 공백을 해소할 수 있는 대상을 대상으로 합니다. 주요 위기상황으로는 급성기 ...
# 표: []...
#
# 생계 지원 (페이지 29, 표 1개)
# 대상: 일정 자격을 갖춘 서비스 제공인력이 대상자의 가정을 방문해 기본돌봄 서비스(재가 돌봄, 가사·이동 지원) 및 방문목욕 서비스를 제공...
# 내용: 최대 72시간의 범위 내에서 지원하며, 가급적 30일 이내에 사용을 권고. 긴급돌봄 서비스를 필요로 하는 대상자 또는 대상자의 친족 및 법정대리...
# 표: ['연번', '2025년 수행 지역', '시·도명']...
#
# 상병수당 지원 (페이지 30, 표 1개)
# 대상: 일정소득 이하 만 15~64세 취업자 (단, 주민등록등본상 시범사업 지역 거주자), 상해, 질병 발생 시 취업자격 및 소득기준 충족자...
# 내용: 상병 발생 시 건보공단에 신청하여 자격심사 후 상병수당 지급. 상병수당 신청용 진단서 발급 시점 이후부터 보장 가능. 질병 및 부상 치료가 종료...
# 표: ['구분', '소득기준', '모형구분']...
#
# 생계지원 (페이지 31, 표 0개)
# 대상: 생계급여･의료급여 수급자, 일본군위안부 피해자, 한부모가족, 도시근로자 월평균소득 70%(3인 기준 533만 3,888원, 1인 가구 90%, ...
# 내용: 안정적 주거생활이 필요한 분들이 보다 저렴하게 주택을 공급받을 수 있도록 지원합니다....
#
# 행복주택 공급 (페이지 32, 표 0개)
# 대상: 대학생, 청년, 신혼부부･한부모가족, 고령자, 주거급여 수급자, 산단 근로자, 창업인...
# 내용: 행복주택 공급에 대한 입주자 선정기준은 대학생, 청년, 신혼부부･한부모가족, 고령자, 주거급여 수급자, 산단 근로자, 창업인 등 다양한 계층을 ...
#
# 행복주택 생계지원 (페이지 33, 표 0개)
# 대상: 무주택 세대구성원(단, 미혼자의 경우 무주택자 요건 적용)으로서 지역전략 산업에 종사하는 등 해당 지방자치 단체장이 지역전략산업 육성을 위하여 ...
# 내용: 행복주택은 무주택 세대구성원을 대상으로 지역전략 산업에 종사하는 사람들을 위한 주택 지원 프로그램입니다. 세대 소득과 자산이 일정 기준 이하인 ...
#
# 분양전환 공공임대주택 공급 (페이지 34, 표 0개)
# 대상: 무주택 세대구성원...
# 내용: 분양전환 공공임대주택 공급은 무주택 세대구성원을 대상으로 합니다. 자격은 소득과 자산에 따라 다르며, 소득은 전년도 도시근로자 가구원수별 월평균...
#
# 공공주택 분양전환 지원 (페이지 35, 표 1개)
# 대상: 입주자 모집 공고일 현재 혼인 중이거나 자녀(미혼인 자녀로 한정, 태아 포함)가 있는 자, 근로자 또는 자영업자로서 5년 이상 소득세를 납부한 ...
# 내용: 공공주택 분양전환 지원은 전용면적 85㎡ 이하 주택을 임대의무기간(6년)동안 시중 임대료 약 80~90% 수준으로 임대거주 후 요건을 갖춘 임차...
# 표: ['자격', '소득', '순자산']...
#
# 매입임대주택 지원 (페이지 36, 표 0개)
# 대상: 소득 및 자산이 일정 기준 이하인 사람...
# 내용: 매입임대주택 지원은 생계급여·의료급여 수급자, 한부모가족 등 무주택세대구성원, 도시근로자가구 월평균소득 50% 이하인 저소득층, 무주택자인 청년...
#
# 다가구주택･다세대·연립주택 매입임대 (페이지 37, 표 1개)
# 대상: 일반 저소득층, 청년, 신혼·신생아, 다자녀, 고령자...
# 내용: 다가구주택･다세대·연립주택을 LH 또는 지역별 지방도시공사에서 매입하여 시세 기준으로 최장 20년간 임대. 청년은 최장 10년간 임대(혼인 시 ...
# 표: ['구분', '지원내용']...
#
# 전세임대 지원 프로그램 (페이지 38, 표 1개)
# 대상: 소득 및 자산 기준을 충족하는 일반 저소득층, 전세임대 수급자, 한부모가족, 무주택 청년, 신혼부부, 다자녀 세대, 소년소녀가정 등...
# 내용: 전세임대 지원 프로그램은 소득 및 자산 기준을 충족하는 다양한 대상자를 대상으로 하며, 각 대상자의 자격 순위에 따라 소득 및 자산 기준이 상이...
# 표: ['구분', '지원대상']...
#
# 전세임대 지원 프로그램 (페이지 39, 표 1개)
# 대상: 일반 저소득층, 청년, 신혼부부, 다자녀, 소년소녀가정 등...
# 내용: 전세임대 지원 프로그램은 수도권, 광역시, 그 외 지역에 거주하는 일반 저소득층, 청년, 신혼부부, 다자녀, 소년소녀가정 등을 대상으로 하며, ...
# 표: ['대상', '구분', '지역']...
#
# 주거취약계층 주거지원 (페이지 40, 표 0개)
# 대상: 쪽방, 고시원, 비닐하우스 등 주택이 아닌 곳에서 3개월 이상 거주자 및 가정폭력피해자, 범죄피해자, 만 18세 미만 아동과 거주하는 최저주거기...
# 내용: 주거취약계층 주거지원은 매입임대, 전세임대, 국민임대 등의 임대주택을 저렴하게 임대하며, 임대기간은 건설, 매임, 전세임대주택 등 입주한 임대주...
#
# 긴급 주거지원 (페이지 41, 표 0개)
# 대상: 주소득자의 사망, 화재 또는 자연재해 등 갑작스러운 위기상황으로 인하여 생계유지가 곤란한 저소득 가구로서 「긴급복지지원법」에 따라 긴급지원대상자...
# 내용: 긴급 주거지원은 주소득자의 사망, 화재 또는 자연재해 등 갑작스러운 위기상황으로 인하여 생계유지가 곤란한 저소득 가구를 대상으로 합니다. 매입임...
#
# 주거급여(맞춤형급여) (페이지 42, 표 1개)
# 대상: 소득인정액이 기준 중위소득의 48% 이하
# - 임차가구: 지역 및 가족 수에 따라 산정한 기준임대료를 상한으로 수급자의 실제임차료 지원
# - 자가가...
# 내용: 주거급여(맞춤형급여)은 소득인정액이 기준 중위소득의 48% 이하인 가구를 대상으로, 임차가구와 자가가구에 대한 주거지원을 제공합니다. 임차가구는...
# 표: ['구분', '경보수', '중보수']...
#
# 슬레이트 처리 지원 (페이지 43, 표 0개)
# 대상: 슬레이트로 된 건축물 지붕 및 벽체 건축물 소유자...
# 내용: 슬레이트로 된 건축물의 지붕철거 및 처리를 지원하며, 취약계층의 경우 지붕철거 후 개량까지 지원합니다....
#
# 고효율조명기기 무상교체 지원 (페이지 44, 표 0개)
# 대상: 저소득층, 사회복지시설...
# 내용: 저소득층, 사회복지시설을 대상으로 고효율 LED 조명기기로의 무상 교체를 지원합니다. LED 조명기기 교체를 통해 에너지 절감을 목적으로 합니다...
#
# 에너지바우처 (페이지 45, 표 0개)
# 대상: 「국민기초생활 보장법」에 따른 생계･의료·주거·교육급여 수급 세대 중 노인, 영유아, 장애인, 임산부, 중증질환자, 희귀질환자, 중증난치질환자,...
# 내용: 에너지 소외계층을 대상으로 전기, 도시가스, 지역난방, 등유, LPG 등을 구입할 수 있는 전자바우처(가구당 평균 367,000원)을 지원합니다...
#
# 사회취약계층 환경성질환 예방사업 (페이지 46, 표 0개)
# 대상: 어려운 경제사정으로 생활이 곤란한 가구(자활급여를 받는 차상위자, 장애수당 또는 장애아동수당 수급자, 생계급여･주거급여·의료급여·교육급여 수급자...
# 내용: 사회취약계층 환경성질환 예방사업은 어려운 경제사정으로 생활이 곤란한 가구를 대상으로 실내환경 오염물질 진단 및 컨설팅, 친환경 주거개선 지원을 ...
#
# 저소득층 에너지효율 개선 (페이지 47, 표 0개)
# 대상: 기초생활수급가구, 차상위계층, 복지사각지대(기초지자체 추천), 사회복지시설 등...
# 내용: 저소득층을 대상으로 한 에너지효율 개선 사업으로, 주택의 노후 주택 에너지 사용 환경을 개선하여 냉방 및 난방 지원을 제공합니다. 주택 소유주의...
#
# 전기요금 복지할인 대상 취약계층 고효율가전 구매지원 (페이지 48, 표 0개)
# 대상: 전기요금 복지할인을 받고 있는 기초생활수급자, 국가유공자(1~3급), 장애의 정도가 심한 장애인(1~3급), 차상위계층 등...
# 내용: 에너지효율등급 1등급 가전제품 구매 시 구매금액의 15~30% 지원(가구당 30만 원 한도). 냉장고, 세탁기, 에어컨, TV 등 고효율 가전제...
#
# 주거안정자금지원 (페이지 49, 표 0개)
# 대상: 부부합산 연소득이 6천만 원 이하(생애최초 주택구입자 및 2자녀 이상 가구 7천만 원, 신혼가구 8.5천만 원) 및 순자산가액 4.88억 원 이...
# 내용: 주거안정자금지원은 내집 마련을 꿈꾸는 저소득 가구에게 주택구입자금 또는 전세자금을 낮은 금리로 지원합니다. 주택도시기금 수탁은행을 방문하거나 온...
#
# 버팀목 전세자금 대출 (페이지 50, 표 0개)
# 대상: 부부합산 연소득이 5천만 원(2자녀 이상 가구, 혁신도시 이전 공공기관 종사자, 타지역으로 이주하는 재개발구역내 세입자 등은 6,000만 원, ...
# 내용: 부부합산 연소득 5천만 원 이하, 순자산가액 3.37억 원 이하인 만 19세 이상 무주택세대주를 대상으로 함. 전세보증금은 수도권 3억 원 이하...
#
# 주거안정 월세대출 (페이지 51, 표 0개)
# 대상: 보증금 1억 원 이하 및 월세 60만 원 이하의 전용면적 85㎡ 이하(읍･면지역 100㎡) 주택 월세계약을 체결하고 부부합산 순자산가액이 3억 ...
# 내용: 월세자금을 저금리(우대형 1.3%, 일반형 1.8%)로 매월 60만 원까지 2년간 최대 1,440만 원 대출...
#
# 전세금안심대출보증 (페이지 52, 표 0개)
# 대상: 전세보증금이 수도권 7억 원 이하(그 외 지역 5억 원 이하)인 전세계약을 체결하고, 전세보증금의 5% 이상을 지급한 만 19세 이상의 개인 임...
# 내용: 전세보증금안심대출보증은 전세계약을 체결한 후 전세보증금의 5% 이상을 지급한 만 19세 이상의 개인 임차인을 대상으로 합니다. 전세자금대출 시 ...
#
# 국민행복기금 채무조정 (페이지 53, 표 0개)
# 대상: 국민행복기금이 금융기관 등으로부터 인수한 연체채권 관련 대상자...
# 내용: 국민행복기금 채무조정은 채무자의 상황(연령, 연체기간, 소득 등)에 따라 원금 감면(원금의 20~70%, 특수 채무자는 최대 90%)과 상환기간...
#
# 신용회복위원회 개인채무조정 (페이지 54, 표 1개)
# 대상: 채무자...
# 내용: 신용회복위원회에서는 15억 원 이하의 채무자를 대상으로 연체기간에 따라 상환기간 연장, 이자율 조정, 채무감면, 분할상환 등을 지원합니다. 지원...
# 표: ['구분', '지원내용', '지원대상']...
#
# 생계지원 (페이지 55, 표 1개)
# 대상: 만 65세 미만의 기준 중위소득 70% 이하 계층 중 가사･간병 서비스가 필요한 자...
# 내용: 가사 및 간병 서비스가 필요한 자를 대상으로 한 달에 일정시간 서비스를 이용할 수 있는 이용권(바우처)을 지원하며, 쌀 할인판매 서비스도 제공합...
# 표: ['구분', '양곡대금(개인부담)']...
